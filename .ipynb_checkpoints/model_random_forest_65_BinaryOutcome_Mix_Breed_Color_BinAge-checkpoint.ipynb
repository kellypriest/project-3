# %% [markdown]
# ## Reading in data and taking a quick look at some charts

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Read in csv
df = pd.read_csv("Austin_Animal_Center_Outcomes.csv")

# %%
# Take a quick peak at charts

# Top Breeds
# df['Breed'].value_counts().head(20).plot.bar()

# Top Outcome_Types
# df['Breed'].value_counts().head(20).plot.bar()

# Sex split?
# df['Sex'].value_counts().head(20).plot.bar()

# Fixed?
df['Fixed'].value_counts().head(20).plot.bar()

# Age chart
# bins= [0,24,72,120]
# plt.hist(df.Age_month, bins=bins, edgecolor="k")
# plt.xticks(bins)
# plt.show()

# %%
df.loc[250:300, :]
# Out:
#     Animal_ID        Name                DateTime               MonthYear  \
# 250   A809527    *Cricket        12/11/2019 16:17        12/11/2019 16:17
# 251   A797472         NaN  06/13/2019 06:59:00 PM  06/13/2019 06:59:00 PM
# 252   A742456      *Arrow  02/14/2017 06:27:00 PM  02/14/2017 06:27:00 PM
# 253   A721330       *Glen          3/5/2016 17:40          3/5/2016 17:40
# 254   A697339         NaN  02/23/2015 06:36:00 PM  02/23/2015 06:36:00 PM
# 255   A695918  Clementine  01/29/2015 05:59:00 PM  01/29/2015 05:59:00 PM
# 256   A809888         NaN         12/4/2019 12:05         12/4/2019 12:05
# 257   A774855         NaN         7/10/2018 19:10         7/10/2018 19:10
# 258   A750857     *Cinder  07/28/2017 10:37:00 PM  07/28/2017 10:37:00 PM
# 259   A762939         NaN  11/30/2017 12:00:00 AM  11/30/2017 12:00:00 AM
# 260   A706606        Boyd  07/23/2015 02:09:00 PM  07/23/2015 02:09:00 PM
# 261   A737771         NaN         11/4/2016 15:37         11/4/2016 15:37
# 262   A682955         NaN          7/5/2014 16:49          7/5/2014 16:49
# 263   A673459        Jack  03/23/2014 06:31:00 PM  03/23/2014 06:31:00 PM
# 264   A704911      *Miles  07/28/2015 07:04:00 PM  07/28/2015 07:04:00 PM
# 265   A702276         NaN         5/11/2015 17:41         5/11/2015 17:41
# 266   A797356     Ratitas         6/12/2019 16:10         6/12/2019 16:10
# 267   A762279         NaN  11/17/2017 02:51:00 PM  11/17/2017 02:51:00 PM
# 268   A693272     *Kodiak  01/31/2015 01:33:00 PM  01/31/2015 01:33:00 PM
# 269   A711264      Merlin  10/24/2015 06:23:00 PM  10/24/2015 06:23:00 PM
# 270   A810713         NaN  12/22/2019 12:40:00 PM  12/22/2019 12:40:00 PM
# 271   A689231      Picqui  11/30/2014 05:55:00 PM  11/30/2014 05:55:00 PM
# 272   A778181         NaN  08/14/2018 11:42:00 AM  08/14/2018 11:42:00 AM
# 273   A807293         NaN  10/27/2019 05:51:00 PM  10/27/2019 05:51:00 PM
# 274   A810161      Lizzie        12/12/2019 16:23        12/12/2019 16:23
# 275   A765587    *Bellamy  01/24/2018 12:00:00 AM  01/24/2018 12:00:00 AM
# 276   A698561         NaN          5/6/2015 17:48          5/6/2015 17:48
# 277   A778070         NaN  08/14/2018 11:41:00 AM  08/14/2018 11:41:00 AM
# 278   A764257         NaN  12/26/2017 05:15:00 PM  12/26/2017 05:15:00 PM
# 279   A752220        Jack  06/23/2017 05:38:00 PM  06/23/2017 05:38:00 PM
# 280   A774738       Benny  06/23/2018 05:52:00 PM  06/23/2018 05:52:00 PM
# 281   A797588         NaN  06/24/2019 12:45:00 PM  06/24/2019 12:45:00 PM
# 282   A766838         NaN  02/21/2018 04:50:00 PM  02/21/2018 04:50:00 PM
# 283   A704221     *Rickon  07/26/2015 06:27:00 PM  07/26/2015 06:27:00 PM
# 284   A749378       Riley  05/14/2017 01:24:00 PM  05/14/2017 01:24:00 PM
# 285   A790090         NaN          3/4/2019 17:53          3/4/2019 17:53
# 286   A679157         NaN  06/30/2014 05:15:00 PM  06/30/2014 05:15:00 PM
# 287   A704677       Gizmo          8/2/2015 17:56          8/2/2015 17:56
# 288   A731684         Jax         8/12/2016 17:04         8/12/2016 17:04
# 289   A807135         NaN  12/13/2019 04:50:00 PM  12/13/2019 04:50:00 PM
# 290   A778179         NaN  08/14/2018 11:42:00 AM  08/14/2018 11:42:00 AM
# 291   A697017        Sady  02/20/2015 05:47:00 PM  02/20/2015 05:47:00 PM
# 292   A731091      Jackie  07/25/2016 05:55:00 PM  07/25/2016 05:55:00 PM
# 293   A679605         NaN  05/23/2014 04:24:00 PM  05/23/2014 04:24:00 PM
# 294   A739585         NaN         12/6/2016 13:30         12/6/2016 13:30
# 295   A748988         NaN          5/9/2017 16:03          5/9/2017 16:03
# 296   A680211         NaN  05/31/2014 11:31:00 AM  05/31/2014 11:31:00 AM
# 297   A752395         NaN  06/26/2017 03:05:00 PM  06/26/2017 03:05:00 PM
# 298   A769130         NaN          4/3/2018 16:16          4/3/2018 16:16
# 299   A682954         NaN          7/5/2014 16:49          7/5/2014 16:49
# 300   A681574      *Scout          7/9/2014 17:57          7/9/2014 17:57
#
#     Date_of_Birth     Outcome_Type Outcome_Subtype     Fixed     Sex  \
# 250    10/18/2019         Adoption          Foster    Spayed  Female
# 251    04/24/2019         Transfer         Partner    Intact  Female
# 252    12/22/2016         Adoption          Foster    Spayed  Female
# 253      1/9/2016         Adoption          Foster  Neutered    Male
# 254    12/30/2014         Adoption             NaN    Spayed  Female
# 255    11/30/2014         Adoption             NaN    Spayed  Female
# 256    10/19/2019         Transfer         Partner    Intact  Female
# 257    05/21/2018         Transfer         Partner    Intact    Male
# 258      6/1/2017         Adoption          Foster    Spayed  Female
# 259    09/30/2017         Transfer         Partner    Intact  Female
# 260    05/27/2015         Adoption             NaN    Intact    Male
# 261    09/19/2016         Transfer         Partner    Intact  Female
# 262      5/5/2014         Transfer         Partner    Intact    Male
# 263    01/24/2014         Adoption          Foster  Neutered    Male
# 264      6/2/2015         Adoption             NaN  Neutered    Male
# 265    03/27/2015         Transfer         Partner    Intact    Male
# 266    04/23/2019       Euthanasia       Suffering    Intact    Male
# 267     10/2/2017         Transfer         Partner    Intact    Male
# 268     12/5/2014         Adoption             NaN  Neutered    Male
# 269    08/28/2015         Adoption          Foster  Neutered    Male
# 270    11/13/2019         Transfer         Partner    Intact  Female
# 271    09/30/2014         Transfer         Partner    Spayed  Female
# 272    06/25/2018         Transfer         Partner    Intact    Male
# 273    08/30/2019         Adoption             NaN    Spayed  Female
# 274    10/15/2019         Adoption             NaN    Spayed  Female
# 275    12/15/2017         Transfer         Partner    Intact    Male
# 276     3/11/2015         Adoption             NaN  Neutered    Male
# 277    06/25/2018         Transfer         Partner    Intact    Male
# 278    10/26/2017         Transfer         Partner    Intact  Female
# 279    04/23/2017         Adoption             NaN  Neutered    Male
# 280    04/27/2018         Adoption             NaN  Neutered    Male
# 281      5/2/2019         Adoption             NaN  Neutered    Male
# 282    12/26/2017         Adoption             NaN  Neutered    Male
# 283      6/1/2015         Adoption          Foster  Neutered    Male
# 284    03/14/2017         Transfer         Partner    Intact    Male
# 285    01/20/2019  Return to Owner             NaN    Intact  Female
# 286      5/5/2014         Adoption          Foster  Neutered    Male
# 287      6/3/2015         Adoption          Foster  Neutered    Male
# 288    06/17/2016         Adoption          Foster  Neutered    Male
# 289    10/17/2019         Adoption          Foster  Neutered    Male
# 290    06/25/2018         Transfer         Partner    Intact  Female
# 291    12/25/2014         Adoption             NaN    Spayed  Female
# 292    05/25/2016  Return to Owner             NaN    Intact  Female
# 293    04/17/2014         Transfer         Partner    Intact    Male
# 294    10/12/2016         Transfer         Partner    Intact    Male
# 295      4/2/2017         Transfer         Partner    Intact  Female
# 296    04/15/2014         Transfer         Partner    Intact  Female
# 297    05/14/2017         Transfer         Partner    Intact    Male
# 298      2/6/2018         Adoption             NaN    Spayed  Female
# 299      5/5/2014         Transfer         Partner    Intact    Male
# 300    05/13/2014         Adoption          Foster  Neutered    Male
#
#      Age_numeric Age_time  Age_month                                Breed  \
# 250            1    month        1.0               Labrador Retriever Mix
# 251            1    month        1.0               Chihuahua Longhair Mix
# 252            1    month        1.0                         Pit Bull Mix
# 253            1    month        1.0                  German Shepherd Mix
# 254            1    month        1.0             German Shepherd/Pit Bull
# 255            1    month        1.0        Dachshund/Chihuahua Shorthair
# 256            1    month        1.0   Labrador Retriever/German Shepherd
# 257            1    month        1.0                Australian Kelpie Mix
# 258            1    month        1.0      Great Pyrenees/American Bulldog
# 259            1    month        1.0                         Pit Bull Mix
# 260            1    month        1.0              Australian Shepherd Mix
# 261            1    month        1.0               Labrador Retriever Mix
# 262            1    month        1.0             Jack Russell Terrier Mix
# 263            1    month        1.0                Yorkshire Terrier Mix
# 264            1    month        1.0                         Pit Bull Mix
# 265            1    month        1.0                 Miniature Poodle Mix
# 266            1    month        1.0                         Pit Bull Mix
# 267            1    month        1.0                      Plott Hound Mix
# 268            1    month        1.0               Beagle/German Shepherd
# 269            1    month        1.0         Flat Coat Retriever/Papillon
# 270            1    month        1.0                Australian Cattle Dog
# 271            1    month        1.0                  German Shepherd Mix
# 272            1    month        1.0            Australian Cattle Dog Mix
# 273            1    month        1.0               Labrador Retriever Mix
# 274            1    month        1.0                Australian Cattle Dog
# 275            1    month        1.0              Chihuahua Shorthair Mix
# 276            1    month        1.0             Labrador Retriever/Boxer
# 277            1    month        1.0       Australian Cattle Dog/Pit Bull
# 278            1    month        1.0              Chihuahua Shorthair Mix
# 279            1    month        1.0                  Black Mouth Cur Mix
# 280            1    month        1.0                     Collie Rough Mix
# 281            1    month        1.0                        Border Collie
# 282            1    month        1.0               Labrador Retriever Mix
# 283            1    month        1.0              Chihuahua Shorthair Mix
# 284            1    month        1.0               Labrador Retriever Mix
# 285            1    month        1.0                    Alaskan Husky Mix
# 286            1    month        1.0   Labrador Retriever/German Shepherd
# 287            1    month        1.0  Dachshund Wirehair/Miniature Poodle
# 288            1    month        1.0               Labrador Retriever Mix
# 289            1    month        1.0                  Chihuahua Shorthair
# 290            1    month        1.0            Australian Cattle Dog Mix
# 291            1    month        1.0                  German Shepherd Mix
# 292            1    month        1.0                       Toy Poodle Mix
# 293            1    month        1.0                         Pit Bull Mix
# 294            1    month        1.0               Labrador Retriever Mix
# 295            1    month        1.0               Labrador Retriever Mix
# 296            1    month        1.0                  German Shepherd Mix
# 297            1    month        1.0            Australian Cattle Dog Mix
# 298            1    month        1.0               Labrador Retriever Mix
# 299            1    month        1.0             Jack Russell Terrier Mix
# 300            1    month        1.0         Labrador Retriever/Blue Lacy
#
#                    Color
# 250          Black/White
# 251            Black/Tan
# 252          Brown/Black
# 253                  Tan
# 254                Brown
# 255          Black/White
# 256          Brown/White
# 257          Brown/White
# 258          Black/White
# 259          Brown/White
# 260           Buff/White
# 261          Black/White
# 262          White/Brown
# 263        Chocolate/Tan
# 264           Blue/White
# 265              Apricot
# 266            Tan/White
# 267  Brown Brindle/White
# 268          Black/Brown
# 269          Black/White
# 270       Tricolor/White
# 271             Tricolor
# 272                Brown
# 273                Brown
# 274      Blue Tick/Black
# 275                Brown
# 276          White/Cream
# 277                  Tan
# 278           White/Buff
# 279                Brown
# 280                Brown
# 281          Black/White
# 282          Black/Brown
# 283          Brown/White
# 284          Brown/White
# 285            Black/Tan
# 286          Cream/White
# 287               Yellow
# 288          Black/White
# 289          Black/Brown
# 290                Brown
# 291                Sable
# 292          Brown/Black
# 293      Brown/Chocolate
# 294          Black/White
# 295            Black/Tan
# 296                Brown
# 297    Cream/Brown Merle
# 298                  Tan
# 299                Sable
# 300            Tan/White

# %%
df.shape
# Out:
# (66804, 14)

# %% [markdown]
# ## Cleaning
# 1. Drop unnessary columns
# 2. Drop rows where "Outcome_Type" is null
# 3. Drop rows where "Outcome_Type" is Return_To_Owner

# %%
# Quick check for missing values
df.apply(lambda x: sum(x.isnull()/len(df)))
# Out:
# Animal_ID          0.000000
# Name               0.169496
# DateTime           0.000000
# MonthYear          0.000000
# Date_of_Birth      0.000000
# Outcome_Type       0.000000
# Outcome_Subtype    0.688567
# Fixed              0.000015
# Sex                0.005673
# Age_numeric        0.000000
# Age_time           0.000000
# Age_month          0.000000
# Breed              0.000000
# Color              0.000000
# dtype: float64

# %%
# Drop unnessary columns
df2 = df.drop(columns=['Animal_ID', 'Name', 'DateTime', 'MonthYear', 'Date_of_Birth', 'Outcome_Subtype', 
                       'Age_numeric', 'Age_time' ])

# %%
df2.shape
# df2.head()
# Out:
# (66804, 6)

# %%
# Drop rows where Outcome_Type is null

df2 = df2.loc[df2.Outcome_Type.notna(), ["Outcome_Type", "Fixed", "Sex", "Age_month", "Breed" ,"Color"]]

# %%
# Check for more nulls
df2.head()
df2.apply(lambda x: sum(x.isnull()/len(df2)))
df2.shape
# Out:
# (66804, 6)

# %%
# Have to fix the following columns "Fixed" and "Sex"
df2 = df2.dropna(axis=0, subset=["Fixed", "Sex"])

# %%
# Verify that nulls from "Fixed" and "Sex" have been dropped
df2.apply(lambda x: sum(x.isnull()/len(df2)))
df2.shape
# Out:
# (66425, 6)

# %%
# df2.groupby('Outcome_Type').count()
df2.groupby('Color').count().sort_values('Outcome_Type', ascending=False)
# Out:
#                       Outcome_Type  Fixed   Sex  Age_month  Breed
# Color
# Black/White                   7831   7831  7831       7831   7831
# Brown/White                   3706   3706  3706       3706   3706
# Tan/White                     3584   3584  3584       3584   3584
# Black                         3502   3502  3502       3502   3502
# White                         3464   3464  3464       3464   3464
# ...                            ...    ...   ...        ...    ...
# Cream/Blue                       1      1     1          1      1
# Chocolate/Yellow                 1      1     1          1      1
# Chocolate/Red Tick               1      1     1          1      1
# Chocolate/Liver Tick             1      1     1          1      1
# Yellow/Yellow                    1      1     1          1      1
#
# [369 rows x 5 columns]

# %%
# Drop all rows 'Return to Owner' ???  

df3 = df2.drop(df2[df2.Outcome_Type == "Return to Owner"].index)

# %%
# Verify shape
df3.shape
# Out:
# (48025, 6)

# %%
# Verify group by counts (Return to Owner should be gone)
df3.groupby('Outcome_Type').count()
# Out:
#               Fixed    Sex  Age_month  Breed  Color
# Outcome_Type
# Adoption      31395  31395      31395  31395  31395
# Died            209    209        209    209    209
# Disposal         22     22         22     22     22
# Euthanasia     1694   1694       1694   1694   1694
# Missing          29     29         29     29     29
# Rto-Adopt       498    498        498    498    498
# Transfer      14178  14178      14178  14178  14178

# %%
# Anymore missing values before we move on?  If zero, then we are good.
df3.apply(lambda x: sum(x.isnull()/len(df3)))
# Out:
# Outcome_Type    0.0
# Fixed           0.0
# Sex             0.0
# Age_month       0.0
# Breed           0.0
# Color           0.0
# dtype: float64

# %% [markdown]
# ## Add new features?
# 1. New feature? - Mixed/Pure Breed? - COMPLETED!!
# 2. Split breeds - COMPLETED!!
# 3. Color -  We have 333 unique color combinations. Hot encoding "Color" will create additional X features if we didn't do anything.  This would be unlikely to create a good performing model.
#     *  Option 1 - We take any values occurring fewer than 300 times and places them into the “other” label. We use this to create a new feature called “Top_colors”.  Doing this would reduce 333 unique colors to 30 unique values - COMPLETED!
#     *  Option 2 - Split to primary color vs secondary color?
# 4. Breeds - Hot encoding "Breed" will create additional 1,380 new features if we didn't do anything.
# 5. New feature? - Single color/Multi color?

# %% [markdown]
# #### Creating a Mix/Pure Breed column

# %%
# Make a copy and add new column called Mix, set to 0
df4 = df3.copy()
df4["Mix"]=0
df4.head()
# Out:
#   Outcome_Type   Fixed     Sex  Age_month                   Breed  \
# 0     Adoption  Spayed  Female   1.000000       Border Collie Mix
# 1     Transfer  Intact    Male   0.066667     German Shepherd Mix
# 2     Transfer  Intact    Male   0.066667  Labrador Retriever Mix
# 4     Transfer  Intact  Female   0.066667           Dachshund Mix
# 6     Transfer  Intact  Female   0.066667            Pit Bull Mix
#
#              Color  Mix
# 0  Chocolate/White    0
# 1            Brown    0
# 2      Black/White    0
# 4            Brown    0
# 6  Chocolate/White    0

# %%
df4.loc[200:210, :]
# Out:
#     Outcome_Type   Fixed     Sex  Age_month                        Breed  \
# 200     Transfer  Intact  Female        0.2                    Dachshund
# 201     Transfer  Intact    Male        0.2                    Dachshund
# 205     Transfer  Intact  Female        0.2   German Shepherd/Rottweiler
# 206     Transfer  Intact  Female        0.2  Labrador Retriever/Pit Bull
# 208     Transfer  Intact  Female        0.2              Rat Terrier Mix
# 209     Transfer  Intact  Female        0.2  Labrador Retriever/Pit Bull
# 210     Transfer  Intact    Male        0.2              Rat Terrier Mix
#
#                    Color  Mix
# 200                  Tan    0
# 201                  Tan    0
# 205          Brown/Black    0
# 206        Brown Brindle    0
# 208                White    0
# 209  Brown Brindle/White    0
# 210                White    0

# %%
# Find rows containing word "Mix" and set to 1 (for True)
df4.loc[df4["Breed"].str.contains("Mix"), "Mix"] = 1

# %%
# Verify - any row with the word "Mix" in Breed column should be a 1 in the new Mix column
df4.loc[200:210, :]
# Out:
#     Outcome_Type   Fixed     Sex  Age_month                        Breed  \
# 200     Transfer  Intact  Female        0.2                    Dachshund
# 201     Transfer  Intact    Male        0.2                    Dachshund
# 205     Transfer  Intact  Female        0.2   German Shepherd/Rottweiler
# 206     Transfer  Intact  Female        0.2  Labrador Retriever/Pit Bull
# 208     Transfer  Intact  Female        0.2              Rat Terrier Mix
# 209     Transfer  Intact  Female        0.2  Labrador Retriever/Pit Bull
# 210     Transfer  Intact    Male        0.2              Rat Terrier Mix
#
#                    Color  Mix
# 200                  Tan    0
# 201                  Tan    0
# 205          Brown/Black    0
# 206        Brown Brindle    0
# 208                White    1
# 209  Brown Brindle/White    0
# 210                White    1

# %%
# Rename the breed WITHOUT the word MIX
df4.loc[df4['Breed'].str.contains('Mix'), 'Breed'] = df4.loc[df4['Breed'].str.contains('Mix'), 'Breed'].str.replace(' Mix', '')

# %%
# Verify that the word 'Mix' is no longer part of the description if Mix is equal to 1
df4.loc[200:210, :]
# Out:
#     Outcome_Type   Fixed     Sex  Age_month                        Breed  \
# 200     Transfer  Intact  Female        0.2                    Dachshund
# 201     Transfer  Intact    Male        0.2                    Dachshund
# 205     Transfer  Intact  Female        0.2   German Shepherd/Rottweiler
# 206     Transfer  Intact  Female        0.2  Labrador Retriever/Pit Bull
# 208     Transfer  Intact  Female        0.2                  Rat Terrier
# 209     Transfer  Intact  Female        0.2  Labrador Retriever/Pit Bull
# 210     Transfer  Intact    Male        0.2                  Rat Terrier
#
#                    Color  Mix
# 200                  Tan    0
# 201                  Tan    0
# 205          Brown/Black    0
# 206        Brown Brindle    0
# 208                White    1
# 209  Brown Brindle/White    0
# 210                White    1

# %% [markdown]
# #### Split breed column!

# %%
df4[['Breed_primary','Breed_second']] = df4.Breed.str.split("/", n=1, expand=True)

# %%
df4.head()
df4.loc[200:230, :]
# Out:
#     Outcome_Type   Fixed     Sex  Age_month  \
# 200     Transfer  Intact  Female        0.2
# 201     Transfer  Intact    Male        0.2
# 205     Transfer  Intact  Female        0.2
# 206     Transfer  Intact  Female        0.2
# 208     Transfer  Intact  Female        0.2
# 209     Transfer  Intact  Female        0.2
# 210     Transfer  Intact    Male        0.2
# 213     Transfer  Intact    Male        0.2
# 215     Transfer  Intact  Female        0.2
# 216     Transfer  Intact  Female        0.2
# 218         Died  Intact    Male        0.2
# 219     Adoption  Spayed  Female        1.0
# 220     Transfer  Intact  Female        1.0
# 221     Transfer  Intact  Female        1.0
# 222     Transfer  Intact  Female        1.0
# 223     Transfer  Intact  Female        1.0
# 224     Adoption  Spayed  Female        1.0
# 225     Adoption  Spayed  Female        1.0
# 226     Transfer  Intact  Female        1.0
# 227     Transfer  Intact    Male        1.0
# 229     Adoption  Spayed  Female        1.0
# 230     Transfer  Intact  Female        1.0
#
#                                     Breed                Color  Mix  \
# 200                             Dachshund                  Tan    0
# 201                             Dachshund                  Tan    0
# 205            German Shepherd/Rottweiler          Brown/Black    0
# 206           Labrador Retriever/Pit Bull        Brown Brindle    0
# 208                           Rat Terrier                White    1
# 209           Labrador Retriever/Pit Bull  Brown Brindle/White    0
# 210                           Rat Terrier                White    1
# 213                             Dachshund                  Tan    0
# 215                             Dachshund                  Tan    0
# 216                             Dachshund                  Tan    0
# 218                   Chihuahua Shorthair                Black    1
# 219                                 Boxer            Red/White    1
# 220                              Pit Bull          Brown/White    1
# 221          Flat Coat Retriever/Pit Bull                 Buff    0
# 222                    Labrador Retriever                Black    1
# 223                   Chihuahua Shorthair                Brown    1
# 224                   Chihuahua Shorthair                Brown    1
# 225                   Australian Shepherd           Blue Merle    1
# 226                              Pit Bull           White/Gray    1
# 227  German Shepherd/Cardigan Welsh Corgi             Tricolor    0
# 229          Labrador Retriever/Blue Lacy             Tricolor    0
# 230        American Staffordshire Terrier          Sable/White    1
#
#                       Breed_primary          Breed_second
# 200                       Dachshund                  None
# 201                       Dachshund                  None
# 205                 German Shepherd            Rottweiler
# 206              Labrador Retriever              Pit Bull
# 208                     Rat Terrier                  None
# 209              Labrador Retriever              Pit Bull
# 210                     Rat Terrier                  None
# 213                       Dachshund                  None
# 215                       Dachshund                  None
# 216                       Dachshund                  None
# 218             Chihuahua Shorthair                  None
# 219                           Boxer                  None
# 220                        Pit Bull                  None
# 221             Flat Coat Retriever              Pit Bull
# 222              Labrador Retriever                  None
# 223             Chihuahua Shorthair                  None
# 224             Chihuahua Shorthair                  None
# 225             Australian Shepherd                  None
# 226                        Pit Bull                  None
# 227                 German Shepherd  Cardigan Welsh Corgi
# 229              Labrador Retriever             Blue Lacy
# 230  American Staffordshire Terrier                  None

# %% [markdown]
# #### Handling Color - Option 1 (Selecting Top_Colors)
# * How does option1 effect RF/LogReg models?

# %%
# Check top colors
color_counts = df4['Color'].value_counts()
# print(color_counts)
# print(df3['Color'].nunique())

# # Handling "Color" Option 1
color_others = set(color_counts[color_counts < 300].index)
df4['Top_colors'] = df4['Color'].replace(list(color_others), 'Others')
print(df4['Top_colors'].nunique())
# Out:
# 30

# %%
# Drop Color column?
df4.loc[150:160, :]
# Out:
#     Outcome_Type   Fixed     Sex  Age_month                Breed        Color  \
# 150     Transfer  Intact    Male   0.166667  Chihuahua Shorthair  Black/White
# 151     Transfer  Intact  Female   0.166667     American Bulldog        White
# 152     Transfer  Intact  Female   0.166667  Chihuahua Shorthair   Fawn/Black
# 153     Transfer  Intact    Male   0.166667  Chihuahua Shorthair  Brown/White
# 154     Transfer  Intact  Female   0.166667  Chihuahua Shorthair  Black/White
# 155         Died  Intact    Male   0.166667  Chihuahua Shorthair        Brown
# 156     Transfer  Intact  Female   0.166667     Miniature Poodle        White
# 157     Transfer  Intact  Female   0.166667             Pit Bull  White/Black
# 158     Transfer  Intact  Female   0.166667  Chihuahua Shorthair     Tricolor
# 159     Transfer  Intact  Female   0.166667             Pit Bull  Sable/White
# 160     Transfer  Intact    Male   0.166667             Pit Bull  Sable/White
#
#      Mix        Breed_primary Breed_second   Top_colors
# 150    1  Chihuahua Shorthair         None  Black/White
# 151    1     American Bulldog         None        White
# 152    1  Chihuahua Shorthair         None       Others
# 153    1  Chihuahua Shorthair         None  Brown/White
# 154    1  Chihuahua Shorthair         None  Black/White
# 155    1  Chihuahua Shorthair         None        Brown
# 156    1     Miniature Poodle         None        White
# 157    1             Pit Bull         None  White/Black
# 158    1  Chihuahua Shorthair         None     Tricolor
# 159    1             Pit Bull         None       Others
# 160    1             Pit Bull         None       Others

# %% [markdown]
# #### Handling Color - Option 2 (Split and have intaker check all colors that apply)
# * How does option2 effect RF/LogReg models?

# %%
# Split Top_color column into color1, color2
df4[['Color1','Color2']] = df4.Top_colors.str.split("/", n=1, expand=True)

# %%
df4.loc[150:160, :]
# Out:
#     Outcome_Type   Fixed     Sex  Age_month                Breed        Color  \
# 150     Transfer  Intact    Male   0.166667  Chihuahua Shorthair  Black/White
# 151     Transfer  Intact  Female   0.166667     American Bulldog        White
# 152     Transfer  Intact  Female   0.166667  Chihuahua Shorthair   Fawn/Black
# 153     Transfer  Intact    Male   0.166667  Chihuahua Shorthair  Brown/White
# 154     Transfer  Intact  Female   0.166667  Chihuahua Shorthair  Black/White
# 155         Died  Intact    Male   0.166667  Chihuahua Shorthair        Brown
# 156     Transfer  Intact  Female   0.166667     Miniature Poodle        White
# 157     Transfer  Intact  Female   0.166667             Pit Bull  White/Black
# 158     Transfer  Intact  Female   0.166667  Chihuahua Shorthair     Tricolor
# 159     Transfer  Intact  Female   0.166667             Pit Bull  Sable/White
# 160     Transfer  Intact    Male   0.166667             Pit Bull  Sable/White
#
#      Mix        Breed_primary Breed_second   Top_colors    Color1 Color2
# 150    1  Chihuahua Shorthair         None  Black/White     Black  White
# 151    1     American Bulldog         None        White     White   None
# 152    1  Chihuahua Shorthair         None       Others    Others   None
# 153    1  Chihuahua Shorthair         None  Brown/White     Brown  White
# 154    1  Chihuahua Shorthair         None  Black/White     Black  White
# 155    1  Chihuahua Shorthair         None        Brown     Brown   None
# 156    1     Miniature Poodle         None        White     White   None
# 157    1             Pit Bull         None  White/Black     White  Black
# 158    1  Chihuahua Shorthair         None     Tricolor  Tricolor   None
# 159    1             Pit Bull         None       Others    Others   None
# 160    1             Pit Bull         None       Others    Others   None

# %% [markdown]
# ## Changing to Binary Outcome - Take the dog or Don't take the dog?
# * Positive Outcome is Adoption - Take in the dog
# * Negative Outcome is a combination of Transfer, Euthanized and Death categories - Don't take in the dog

# %%
# Create new BINARY_OUTCOME column and set to 0

df4["Binary_outcome"]=0
df4.head()
# Out:
#   Outcome_Type   Fixed     Sex  Age_month               Breed  \
# 0     Adoption  Spayed  Female   1.000000       Border Collie
# 1     Transfer  Intact    Male   0.066667     German Shepherd
# 2     Transfer  Intact    Male   0.066667  Labrador Retriever
# 4     Transfer  Intact  Female   0.066667           Dachshund
# 6     Transfer  Intact  Female   0.066667            Pit Bull
#
#              Color  Mix       Breed_primary Breed_second       Top_colors  \
# 0  Chocolate/White    1       Border Collie         None  Chocolate/White
# 1            Brown    1     German Shepherd         None            Brown
# 2      Black/White    1  Labrador Retriever         None      Black/White
# 4            Brown    1           Dachshund         None            Brown
# 6  Chocolate/White    1            Pit Bull         None  Chocolate/White
#
#       Color1 Color2  Binary_outcome
# 0  Chocolate  White               0
# 1      Brown   None               0
# 2      Black  White               0
# 4      Brown   None               0
# 6  Chocolate  White               0

# %%
# Find rows containing word "Adoption" and set to 1 (for Positive Outcome)
# All other rows will be 0 (for Negative Outcome)

df4.loc[df4["Outcome_Type"].str.contains("Adoption"), "Binary_outcome"] = 1

# %%
df4.loc[200:300, :]
# Out:
#     Outcome_Type     Fixed     Sex  Age_month                         Breed  \
# 200     Transfer    Intact  Female        0.2                     Dachshund
# 201     Transfer    Intact    Male        0.2                     Dachshund
# 205     Transfer    Intact  Female        0.2    German Shepherd/Rottweiler
# 206     Transfer    Intact  Female        0.2   Labrador Retriever/Pit Bull
# 208     Transfer    Intact  Female        0.2                   Rat Terrier
# ..           ...       ...     ...        ...                           ...
# 296     Transfer    Intact  Female        1.0               German Shepherd
# 297     Transfer    Intact    Male        1.0         Australian Cattle Dog
# 298     Adoption    Spayed  Female        1.0            Labrador Retriever
# 299     Transfer    Intact    Male        1.0          Jack Russell Terrier
# 300     Adoption  Neutered    Male        1.0  Labrador Retriever/Blue Lacy
#
#                  Color  Mix          Breed_primary Breed_second  \
# 200                Tan    0              Dachshund         None
# 201                Tan    0              Dachshund         None
# 205        Brown/Black    0        German Shepherd   Rottweiler
# 206      Brown Brindle    0     Labrador Retriever     Pit Bull
# 208              White    1            Rat Terrier         None
# ..                 ...  ...                    ...          ...
# 296              Brown    1        German Shepherd         None
# 297  Cream/Brown Merle    1  Australian Cattle Dog         None
# 298                Tan    1     Labrador Retriever         None
# 299              Sable    1   Jack Russell Terrier         None
# 300          Tan/White    0     Labrador Retriever    Blue Lacy
#
#         Top_colors         Color1 Color2  Binary_outcome
# 200            Tan            Tan   None               0
# 201            Tan            Tan   None               0
# 205    Brown/Black          Brown  Black               0
# 206  Brown Brindle  Brown Brindle   None               0
# 208          White          White   None               0
# ..             ...            ...    ...             ...
# 296          Brown          Brown   None               0
# 297         Others         Others   None               0
# 298            Tan            Tan   None               1
# 299          Sable          Sable   None               0
# 300      Tan/White            Tan  White               1
#
# [90 rows x 13 columns]

# %% [markdown]
# ## Perform get_dummies  ( Changing categorical values to numeric values )

# %%
# Passing get_dummies on all columns except Outcome_Type and Pet_ageMonths
df4 = pd.get_dummies(data=df4, columns=['Fixed', 'Sex', 'Breed_primary', 'Breed_second', 'Color1', 'Color2','Mix'])

# %%
df4.columns
# Out:
# Index(['Outcome_Type', 'Age_month', 'Breed', 'Color', 'Top_colors',
#        'Binary_outcome', 'Fixed_Intact', 'Fixed_Neutered', 'Fixed_Spayed',
#        'Sex_Female',
#        ...
#        'Color1_White', 'Color1_Yellow', 'Color2_Black', 'Color2_Brown',
#        'Color2_Brown Brindle', 'Color2_Tan', 'Color2_Tricolor', 'Color2_White',
#        'Mix_0', 'Mix_1'],
#       dtype='object', length=394)

# %%
# Drop these columns as they are duplicates
df4 = df4.drop(columns=['Sex_Female', 'Mix_0'])

# %%
df4.shape
# Out:
# (48025, 392)

# %%
# Define X and y
X = df4.drop(['Outcome_Type', 'Binary_outcome','Breed', 'Color', 'Top_colors'], axis="columns")
y = df4[['Binary_outcome']]

# %%
X.shape
# Out:
# (48025, 387)

# %%
y.shape
# Out:
# (48025, 1)

# %% [markdown]
# ## Random Forest model

# %%
# Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Import, initialize, fit and predict
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 10) 
rf_model.fit(X_train, y_train)
predict_y_test = rf_model.predict(X_test)
# Out:
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
# Validate - run accuracy score
from sklearn import metrics
print("Accuracy score: ", metrics.accuracy_score(y_test, predict_y_test))
# Out:
# Accuracy score:  0.7735487632214542

# %%
# RF Feature importance?
feature_list = list(X.columns)
feature_importance = pd.Series(rf_model.feature_importances_, index=feature_list).sort_values(ascending=False) 
print(feature_importance[0:10])
# Out:
# Age_month         0.234999
# Fixed_Intact      0.206512
# Fixed_Spayed      0.079626
# Fixed_Neutered    0.063317
# Sex_Male          0.035907
# Mix_1             0.025692
# Color2_White      0.013855
# Color1_Tan        0.008514
# Color1_Brown      0.008411
# Color1_Black      0.008165
# dtype: float64

# %%
# Validate with cross validation

from sklearn.model_selection import cross_val_score

scores = cross_val_score(rf_model, X, y, cv=10, scoring="accuracy")
print(scores)
# Out:
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [0.908807   0.81990423 0.56423069 0.51800958 0.75036436 0.68992087
#  0.73177843 0.6636818  0.43419409 0.40462307]

# %%
scores.mean()
# Out:
# 0.6485514094992866

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logReg = LogisticRegression()
logReg.fit(X_train, y_train)
# Out:
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {logReg.score(X_train, y_train)}")
print(f"Testing Data Score: {logReg.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8054028541284913
# Testing Data Score: 0.8056966769384526
