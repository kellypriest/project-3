# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Read in csv
df = pd.read_csv("merged_clean3.csv")

# %%
# Find shape
df.shape
# Out:
# (22139, 8)

# %% [markdown]
# #### Cleaning up:
# 1.  Creating a new column called "Mix".  Mix=1 if true, Mix=0 if false
# 2.  Took out the word "Mix" in Breed

# %%
# Make a copy and add new column called Mix, set to 0
new_df = df.copy()
new_df["Mix"]=0
new_df.head()
# Out:
#    CSV_Age Day_mth_year_cat  Pet_ageMonths                    Breed  \
# 0      1.0              day           0.03  Chihuahua Shorthair Mix
# 1      1.0              day           0.03             Pit Bull Mix
# 2      1.0              day           0.03             Pit Bull Mix
# 3      1.0              day           0.03             Pit Bull Mix
# 4      1.0              day           0.03             Pit Bull Mix
#
#                  Color     Outcome_Type   Fixed     Sex  Mix
# 0             Tricolor              NaN  Intact    Male    0
# 1                White              NaN  Intact  Female    0
# 2          White/Black  Return_to_owner  Intact    Male    0
# 3  White/Brown Brindle  Return_to_owner  Intact    Male    0
# 4  Brown Brindle/White  Return_to_owner  Intact  Female    0

# %%
# Find rows containing word "Mix" and set to 1 (for True)
new_df.loc[new_df["Breed"].str.contains("Mix"), "Mix"] = 1

# %%
# Check
new_df.loc[200:300, :]
# Out:
#      CSV_Age Day_mth_year_cat  Pet_ageMonths                    Breed  \
# 200      1.0            month            1.0          Plott Hound Mix
# 201      1.0            month            1.0          Plott Hound Mix
# 202      1.0            month            1.0  Chihuahua Shorthair Mix
# 203      1.0            month            1.0  Chihuahua Shorthair Mix
# 204      1.0            month            1.0            Dachshund Mix
# ..       ...              ...            ...                      ...
# 296      1.0            month            1.0        Whippet/Dachshund
# 297      1.0            month            1.0           Toy Poodle Mix
# 298      1.0            month            1.0  Australian Shepherd Mix
# 299      1.0            month            1.0             Pit Bull Mix
# 300      1.0            month            1.0             Pit Bull Mix
#
#              Color Outcome_Type   Fixed     Sex  Mix
# 200    Brown/Black     Transfer  Intact    Male    1
# 201            Red     Transfer  Intact  Female    1
# 202    Black/Brown   Euthanasia  Intact    Male    1
# 203       Tricolor     Transfer  Intact  Female    1
# 204    Brown/White     Transfer  Intact  Female    1
# ..             ...          ...     ...     ...  ...
# 296          White     Transfer  Intact  Female    0
# 297     Blue/White     Transfer  Intact    Male    1
# 298       Tricolor     Adoption  Intact    Male    1
# 299          Black     Transfer  Intact    Male    1
# 300  Brown Brindle     Transfer  Intact  Female    1
#
# [101 rows x 9 columns]

# %%
# Rename the breed WITHOUT the word MIX
new_df.loc[new_df['Breed'].str.contains('Mix'), 'Breed'] = new_df.loc[df['Breed'].str.contains('Mix'), 'Breed'].str.replace(' Mix', '')

# %%
# Verify that the word 'Mix' is no longer part of the description if Mix is equal to 1
new_df.loc[200:300, :]
# Out:
#      CSV_Age Day_mth_year_cat  Pet_ageMonths                Breed  \
# 200      1.0            month            1.0          Plott Hound
# 201      1.0            month            1.0          Plott Hound
# 202      1.0            month            1.0  Chihuahua Shorthair
# 203      1.0            month            1.0  Chihuahua Shorthair
# 204      1.0            month            1.0            Dachshund
# ..       ...              ...            ...                  ...
# 296      1.0            month            1.0    Whippet/Dachshund
# 297      1.0            month            1.0           Toy Poodle
# 298      1.0            month            1.0  Australian Shepherd
# 299      1.0            month            1.0             Pit Bull
# 300      1.0            month            1.0             Pit Bull
#
#              Color Outcome_Type   Fixed     Sex  Mix
# 200    Brown/Black     Transfer  Intact    Male    1
# 201            Red     Transfer  Intact  Female    1
# 202    Black/Brown   Euthanasia  Intact    Male    1
# 203       Tricolor     Transfer  Intact  Female    1
# 204    Brown/White     Transfer  Intact  Female    1
# ..             ...          ...     ...     ...  ...
# 296          White     Transfer  Intact  Female    0
# 297     Blue/White     Transfer  Intact    Male    1
# 298       Tricolor     Adoption  Intact    Male    1
# 299          Black     Transfer  Intact    Male    1
# 300  Brown Brindle     Transfer  Intact  Female    1
#
# [101 rows x 9 columns]

# %%
new_df.shape
# Out:
# (22139, 9)

# %% [markdown]
# #### Dropping null values in Outcome_Type Column

# %%
# Drop rows where Outcome_Type is null

new_df2 = new_df.loc[df.Outcome_Type.notna(), ["Outcome_Type", "Pet_ageMonths", "Breed", "Color", "Sex", "Fixed", "Mix"]]

# %%
new_df2.loc[200:300, ]
# Out:
#     Outcome_Type  Pet_ageMonths                Breed          Color     Sex  \
# 200     Transfer            1.0          Plott Hound    Brown/Black    Male
# 201     Transfer            1.0          Plott Hound            Red  Female
# 202   Euthanasia            1.0  Chihuahua Shorthair    Black/Brown    Male
# 203     Transfer            1.0  Chihuahua Shorthair       Tricolor  Female
# 204     Transfer            1.0            Dachshund    Brown/White  Female
# ..           ...            ...                  ...            ...     ...
# 296     Transfer            1.0    Whippet/Dachshund          White  Female
# 297     Transfer            1.0           Toy Poodle     Blue/White    Male
# 298     Adoption            1.0  Australian Shepherd       Tricolor    Male
# 299     Transfer            1.0             Pit Bull          Black    Male
# 300     Transfer            1.0             Pit Bull  Brown Brindle  Female
#
#       Fixed  Mix
# 200  Intact    1
# 201  Intact    1
# 202  Intact    1
# 203  Intact    1
# 204  Intact    1
# ..      ...  ...
# 296  Intact    0
# 297  Intact    1
# 298  Intact    1
# 299  Intact    1
# 300  Intact    1
#
# [101 rows x 7 columns]

# %%
# Verify shape
new_df2.shape
# Out:
# (15517, 7)

# %%
# new_df2.groupby('Breed').count().sort_values("Mix", ascending=True)
# Out:
#                                     Outcome_Type  Pet_ageMonths  Color   Sex  \
# Breed
# French Bulldog/Miniature Schnauzer             1              1      1     1
# Great Dane/German Shepherd                     1              1      1     1
# Great Dane/Pit Bull                            1              1      1     1
# Great Dane/Staffordshire                       1              1      1     1
# Great Pyrenees/Australian Shepherd             1              1      1     1
# ...                                          ...            ...    ...   ...
# Australian Cattle Dog                        392            392    392   392
# German Shepherd                              650            650    650   650
# Labrador Retriever                          1414           1414   1414  1414
# Chihuahua Shorthair                         1840           1840   1840  1840
# Pit Bull                                    1966           1966   1966  1966
#
#                                     Fixed   Mix
# Breed
# French Bulldog/Miniature Schnauzer      1     1
# Great Dane/German Shepherd              1     1
# Great Dane/Pit Bull                     1     1
# Great Dane/Staffordshire                1     1
# Great Pyrenees/Australian Shepherd      1     1
# ...                                   ...   ...
# Australian Cattle Dog                 392   392
# German Shepherd                       650   650
# Labrador Retriever                   1414  1414
# Chihuahua Shorthair                  1840  1840
# Pit Bull                             1966  1966
#
# [1197 rows x 6 columns]

# %%
# new_df2.groupby('Breed').filter(lambda x: len(x) > 10)
# Out:
#           Outcome_Type  Pet_ageMonths                               Breed  \
# 2      Return_to_owner           0.03                            Pit Bull
# 3      Return_to_owner           0.03                            Pit Bull
# 4      Return_to_owner           0.03                            Pit Bull
# 5      Return_to_owner           0.03                            Pit Bull
# 6      Return_to_owner           0.03                            Pit Bull
# ...                ...            ...                                 ...
# 22133  Return_to_owner          48.00                  Labrador Retriever
# 22134  Return_to_owner          60.00                            Pit Bull
# 22135         Adoption          24.00                        Carolina Dog
# 22136       Euthanasia         108.00  German Shepherd/Labrador Retriever
# 22137  Return_to_owner          24.00                 Miniature Schnauzer
#
#                      Color     Sex   Fixed  Mix
# 2              White/Black    Male  Intact    1
# 3      White/Brown Brindle    Male  Intact    1
# 4      Brown Brindle/White  Female  Intact    1
# 5      White/Brown Brindle    Male  Intact    1
# 6              White/Brown  Female  Intact    1
# ...                    ...     ...     ...  ...
# 22133                Black  Female  Spayed    1
# 22134                White  Female  Spayed    1
# 22135                  Red  Female  Spayed    1
# 22136          Black/Brown  Female  Spayed    0
# 22137           Gray/White  Female  Spayed    1
#
# [13264 rows x 7 columns]

# %% [markdown]
# #### get_dummies - Changing to numeric values

# %%
# Passing get_dummies on all columns except Outcome_Type and Pet_ageMonths
new_df3 = pd.get_dummies(data=new_df2, columns=['Breed', 'Color', 'Sex', 'Fixed', 'Mix'])

# %%
new_df3.head()
# Out:
#       Outcome_Type  Pet_ageMonths  Breed_Affenpinscher  Breed_Afghan Hound  \
# 2  Return_to_owner           0.03                    0                   0
# 3  Return_to_owner           0.03                    0                   0
# 4  Return_to_owner           0.03                    0                   0
# 5  Return_to_owner           0.03                    0                   0
# 6  Return_to_owner           0.03                    0                   0
#
#    Breed_Airedale Terrier  Breed_Airedale Terrier/Labrador Retriever  \
# 2                       0                                          0
# 3                       0                                          0
# 4                       0                                          0
# 5                       0                                          0
# 6                       0                                          0
#
#    Breed_Airedale Terrier/Miniature Schnauzer  Breed_Akita  \
# 2                                           0            0
# 3                                           0            0
# 4                                           0            0
# 5                                           0            0
# 6                                           0            0
#
#    Breed_Akita/Australian Cattle Dog  Breed_Akita/Chow Chow  ...  \
# 2                                  0                      0  ...
# 3                                  0                      0  ...
# 4                                  0                      0  ...
# 5                                  0                      0  ...
# 6                                  0                      0  ...
#
#    Color_Yellow/Black  Color_Yellow/White  Color_Yellow/Yellow  Sex_Female  \
# 2                   0                   0                    0           0
# 3                   0                   0                    0           0
# 4                   0                   0                    0           1
# 5                   0                   0                    0           0
# 6                   0                   0                    0           1
#
#    Sex_Male  Fixed_Intact  Fixed_Neutered  Fixed_Spayed  Mix_0  Mix_1
# 2         1             1               0             0      0      1
# 3         1             1               0             0      0      1
# 4         0             1               0             0      0      1
# 5         1             1               0             0      0      1
# 6         0             1               0             0      0      1
#
# [5 rows x 1468 columns]

# %%
new_df3.shape
# Out:
# (15517, 1468)

# %%
# Drop these columns as they are duplicates
new_df3 = new_df3.drop(columns=['Sex_Female', 'Mix_0'])

# %%
# Verify that 2 columns dropped
new_df3.shape
# Out:
# (15517, 1466)

# %%
# Define X and y
X = new_df3.drop(['Outcome_Type'], axis="columns")
y = new_df3[['Outcome_Type']]

# %%
X.shape
# Out:
# (15517, 1465)

# %%
y.shape
# Out:
# (15517, 1)

# %% [markdown]
# ### random forest

# %%
# Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Import, initialize, fit and predict
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 10) 
rf_model.fit(X_train, y_train)
predict_y_test = rf_model.predict(X_test)
# Out:
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
# Validate - run accuracy score
from sklearn import metrics
print("Accuracy score: ", metrics.accuracy_score(y_test, predict_y_test)) # actual test vs new predict test
# Out:
# Accuracy score:  0.5162371134020619

# %%
# Validate with cross validation

from sklearn.model_selection import cross_val_score

scores = cross_val_score(rf_model, X, y, cv=10, scoring="accuracy")
print(scores)
# Out:
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\Anaconda3\envs\pythondata\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [0.53350515 0.56701031 0.25902062 0.35889175 0.34407216 0.45167526
#  0.43556701 0.14700193 0.379755   0.38426821]

# %%
scores.mean()
# Out:
# 0.38607674131089353

# %% [markdown]
# ### Logistic Regression

# %%
df = pd.read_csv("merged_clean3.csv")

# %%
df2 = df.loc[df.Outcome_Type.notna(), :]
df2.shape

# %%
df3 = df.loc[df.Outcome_Type.notna(), ["Outcome_Type"]]

# %%
df3.shape

# %%
df4 = df2[["Pet_ageMonths", "Breed", "Color", "Fixed", "Sex"]]

# %%
X = pd.get_dummies(df4)
X.shape

# %%
y = df3
y.shape
print(y)

# %%
 from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logReg = LogisticRegression()

# %%
logReg.fit(X_train, y_train)

# %%
print(f"Training Data Score: {logReg.score(X_train, y_train)}")
print(f"Testing Data Score: {logReg.score(X_test, y_test)}")

# %%
predictions = logReg.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10]}")

# %%
 pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
