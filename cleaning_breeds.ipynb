# %%
import pandas as pd

# %%
lky_data = pd.read_csv("LouisvilleClean.csv")
lky_data
# Out:
#        Unnamed: 0    PrimaryColor            PrimaryBreed  \
# 0               4           WHITE        PIT BULL TERRIER
# 1              51           BLACK           BORDER COLLIE
# 2              69             TAN        GOLDEN RETRIEVER
# 3              99           WHITE      LABRADOR RETRIEVER
# 4             103           BLACK        PIT BULL TERRIER
# ...           ...             ...                     ...
# 42817      150835         APRICOT  DANDIE DINMONT TERRIER
# 42818      150836           BLACK  DACHSHUND - WIREHAIRED
# 42819      150837  YELLOW BRINDLE               GREYHOUND
# 42820      150838           CREAM           CAIRN TERRIER
# 42821      150839           BLACK      MINIATURE PINSCHER
#
#       IntakeInternalStatus IntakeAsilomarStatus ReproductiveStatusAtIntake  \
# 0                   NORMAL              HEALTHY                    FERTILE
# 1                   NORMAL              HEALTHY                    ALTERED
# ...

# %%
df = lky_data.drop(columns=['Unnamed: 0',
                       'IntakeInternalStatus', 
                       'IntakeAsilomarStatus', 
                       'ReproductiveStatusAtIntake',
                       'AgeInMonths',
                        'DurationInShelter',
                        'Binary_outcome'])
df
# Out:
#          PrimaryColor            PrimaryBreed OutcomeType BreedCategory  \
# 0               WHITE        PIT BULL TERRIER        EUTH          Pure
# 1               BLACK           BORDER COLLIE    ADOPTION           Mix
# 2                 TAN        GOLDEN RETRIEVER    ADOPTION           Mix
# 3               WHITE      LABRADOR RETRIEVER    ADOPTION          Pure
# 4               BLACK        PIT BULL TERRIER        EUTH          Pure
# ...               ...                     ...         ...           ...
# 42817         APRICOT  DANDIE DINMONT TERRIER    ADOPTION           Mix
# 42818           BLACK  DACHSHUND - WIREHAIRED    ADOPTION          Pure
# 42819  YELLOW BRINDLE               GREYHOUND    ADOPTION           Mix
# 42820           CREAM           CAIRN TERRIER    ADOPTION          Pure
# 42821           BLACK      MINIATURE PINSCHER    TRANSFER          Pure
#
#       Pet_age_category     Sex
# 0                Young    Male
# 1                Young  Female
# ...

# %%
df.PrimaryBreed.unique()
# Out:
# array(['PIT BULL TERRIER', 'BORDER COLLIE', 'GOLDEN RETRIEVER',
#        'LABRADOR RETRIEVER', 'ST BERNARD', 'WIRE-HAIRED POINTING GRIFFON',
#        'BEAGLE', 'PLOTT HOUND', 'BICHON FRISE', 'GERMAN SHEPHERD DOG',
#        'TIBETAN TERRIER', 'SHETLAND SHEEPDOG', 'JACK RUSS TER', 'PUG',
#        'MANCHESTER TERRIER', 'CHIHUAHUA', 'PEKINGESE', 'CHOW CHOW',
#        'PARSON (JACK) RUSSELL TERRIER', 'IRISH TERRIER', 'BASSET HOUND',
#        'ROTTWEILER', 'FRENCH BULLDOG', 'FOX TERRIER', 'SIBERIAN HUSKY',
#        'POMERANIAN', 'BOXER', 'RAT TERRIER', 'GREAT DANE', 'POODLE - TOY',
#        'AMERICAN STAFFORDSHIRE TERRIER', 'SCHNAUZER - MINIATURE',
#        'AUSTRALIAN SHEPHERD', 'WEIMARANER', 'DOBERMAN PINSCHER',
#        'MASTIFF', 'SHIH TZU', 'FINNISH SPITZ', 'POODLE - MINIATURE',
#        'BOSTON TERRIER', 'YORKSHIRE TERRIER', 'AMERICAN BULLDOG',
#        'MINIATURE PINSCHER', 'BLACK AND TAN COONOUND', 'COCKER SPANIEL',
# ...

# %%
breed_counts = df.PrimaryBreed.value_counts()
breed_counts.head(30)
# Out:
# PIT BULL TERRIER                  8298
# LABRADOR RETRIEVER                5080
# BEAGLE                            2966
# GERMAN SHEPHERD DOG               2897
# CHIHUAHUA                         2146
# BOXER                             1698
# SHIH TZU                          1119
# ROTTWEILER                        1108
# BORDER COLLIE                      916
# JACK RUSS TER                      915
# CHOW CHOW                          909
# DACHSHUND                          667
# POODLE - MINIATURE                 612
# YORKSHIRE TERRIER                  605
# AUSTRALIAN SHEPHERD                515
# SIBERIAN HUSKY                     509
# POMERANIAN                         496
# AMERICAN STAFFORDSHIRE TERRIER     447
# COCKER SPANIEL                     439
# PUG                                438
# MINIATURE PINSCHER                 422
# GOLDEN RETRIEVER                   417
# AUSTRALIAN CATTLE DOG              376
# SCHNAUZER - MINIATURE              347
# ...

# %%
df.loc[df['PrimaryBreed'].str.contains('AMERICAN STAFFORDSHIRE TERRIER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('AMERICAN STAFFORDSHIRE TERRIER'), 'PrimaryBreed'].str.replace('AMERICAN STAFFORDSHIRE TERRIER', 'STAFFORDSHIRE')

# %%
df.loc[df['PrimaryBreed'].str.contains('STAFFORDSHIRE'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('STAFFORDSHIRE'), 'PrimaryBreed'].str.replace('STAFFORDSHIRE', 'AMERICAN STAFFORDSHIRE TERRIER')

# %%
df.loc[df['PrimaryBreed'].str.contains('AMERICAN STAFFORDSHIRE TERRIER BULL TERRIER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('AMERICAN STAFFORDSHIRE TERRIER BULL TERRIER'), 'PrimaryBreed'].str.replace('AMERICAN STAFFORDSHIRE TERRIER BULL TERRIER', 'AMERICAN STAFFORDSHIRE TERRIER')

# %%
df.loc[df['PrimaryBreed'].str.contains('AMERICAN PIT BULL TERRIER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('AMERICAN PIT BULL TERRIER'), 'PrimaryBreed'].str.replace('AMERICAN PIT BULL TERRIER', 'PIT BULL TERRIER')

# %%
df.loc[df['PrimaryBreed'].str.contains('QUEENSLAND HEELER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('QUEENSLAND HEELER'), 'PrimaryBreed'].str.replace('QUEENSLAND HEELER', 'AUSTRALIAN CATTLE DOG')

# %%
df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - SMOOTH COATED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - SMOOTH COATED'), 'PrimaryBreed'].str.replace('CHIHUAHUA - SMOOTH COATED', 'CHIHUAHUA')
df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - LONG HAIRED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - LONG HAIRED'), 'PrimaryBreed'].str.replace('CHIHUAHUA - LONG HAIRED', 'CHIHUAHUA')

# %%
df.loc[df['PrimaryBreed'].str.contains('FOX TERRIER - WIREHAIRED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('FOX TERRIER - WIREHAIRED'), 'PrimaryBreed'].str.replace('FOX TERRIER - WIREHAIRED', 'FOX TERRIER')
df.loc[df['PrimaryBreed'].str.contains('FOX TERRIER - SMOOTH'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('FOX TERRIER - SMOOTH'), 'PrimaryBreed'].str.replace('FOX TERRIER - SMOOTH', 'FOX TERRIER')

# %%
df.loc[df['PrimaryBreed'].str.contains('COLLIE - ROUGH'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('COLLIE - ROUGH'), 'PrimaryBreed'].str.replace('COLLIE - ROUGH', 'COLLIE')
df.loc[df['PrimaryBreed'].str.contains('COLLIE - SMOOTH'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('COLLIE - SMOOTH'), 'PrimaryBreed'].str.replace('COLLIE - SMOOTH', 'COLLIE')

# %%
df.loc[df['PrimaryBreed'].str.contains('ST BERNARD - ROUGH COATED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('ST BERNARD - ROUGH COATED'), 'PrimaryBreed'].str.replace('ST BERNARD - ROUGH COATED', 'ST BERNARD')
df.loc[df['PrimaryBreed'].str.contains('ST BERNARD - SMOOTH COATED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('ST BERNARD - SMOOTH COATED'), 'PrimaryBreed'].str.replace('ST BERNARD - SMOOTH COATED', 'ST BERNARD')

# %%
df.loc[df['PrimaryBreed'].str.contains('DACHSHUND - LONGHAIRED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('DACHSHUND - LONGHAIRED'), 'PrimaryBreed'].str.replace('DACHSHUND - LONGHAIRED', 'DACHSHUND')
df.loc[df['PrimaryBreed'].str.contains('DACHSHUND - WIREHAIRED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('DACHSHUND - WIREHAIRED'), 'PrimaryBreed'].str.replace('DACHSHUND - WIREHAIRED', 'DACHSHUND')
