# %%
import pandas as pd

# %%
## read in austin data
atx_data = pd.read_csv("AustinClean.csv")
atx_data
# Out:
#        Unnamed: 0 OutcomeType     Sex    AgeMonth  \
# 0               0    Adoption  Female    1.000000
# 1               1    Transfer    Male    0.066667
# 2               2    Transfer    Male    0.066667
# 3               4    Transfer  Female    0.066667
# 4               6    Transfer  Female    0.066667
# ...           ...         ...     ...         ...
# 48020       66772  Euthanasia    Male  216.000000
# 48021       66774    Adoption    Male  216.000000
# 48022       66786  Euthanasia  Female  228.000000
# 48023       66787    Transfer    Male  228.000000
# 48024       66790  Euthanasia  Female  228.000000
#
#                                      Breed            Color BreedCategory  \
# 0                        Border Collie Mix  Chocolate/White           Mix
# 1                      German Shepherd Mix            Brown           Mix
# 2                   Labrador Retriever Mix      Black/White           Mix
# ...

# %%
#drop columns
atx_df = atx_data.drop(columns=['Unnamed: 0', 
                       'AgeMonth', 
                       'Breed',
                       'Color',
                       'SecondaryBreed',
                        'SecondColor',
                        'Binary_outcome'])
atx_df
# Out:
#       OutcomeType     Sex BreedCategory             PrimaryBreed PrimaryColor  \
# 0        Adoption  Female           Mix        Border Collie Mix    Chocolate
# 1        Transfer    Male           Mix      German Shepherd Mix        Brown
# 2        Transfer    Male           Mix   Labrador Retriever Mix        Black
# 3        Transfer  Female           Mix            Dachshund Mix        Brown
# 4        Transfer  Female           Mix             Pit Bull Mix    Chocolate
# ...           ...     ...           ...                      ...          ...
# 48020  Euthanasia    Male           Mix  Miniature Schnauzer Mix         Gray
# 48021    Adoption    Male           Mix   Chihuahua Longhair Mix        White
# 48022  Euthanasia  Female          Pure         Miniature Poodle        White
# 48023    Transfer    Male           Mix  Chihuahua Shorthair Mix        Brown
# 48024  Euthanasia  Female           Two       Chihuahua Longhair        White
#
#       Pet_age_category
# ...

# %%
## read in luoisville data
lky_data = pd.read_csv("LouisvilleClean.csv")
lky_data
# Out:
#        Unnamed: 0    PrimaryColor            PrimaryBreed  \
# 0               4           WHITE        PIT BULL TERRIER
# 1              51           BLACK           BORDER COLLIE
# 2              69             TAN        GOLDEN RETRIEVER
# 3              99           WHITE      LABRADOR RETRIEVER
# 4             103           BLACK        PIT BULL TERRIER
# ...           ...             ...                     ...
# 42817      150835         APRICOT  DANDIE DINMONT TERRIER
# 42818      150836           BLACK  DACHSHUND - WIREHAIRED
# 42819      150837  YELLOW BRINDLE               GREYHOUND
# 42820      150838           CREAM           CAIRN TERRIER
# 42821      150839           BLACK      MINIATURE PINSCHER
#
#       IntakeInternalStatus IntakeAsilomarStatus ReproductiveStatusAtIntake  \
# 0                   NORMAL              HEALTHY                    FERTILE
# 1                   NORMAL              HEALTHY                    ALTERED
# ...

# %%
##drop columns
lky_df = lky_data.drop(columns=['Unnamed: 0',
                       'IntakeInternalStatus', 
                       'IntakeAsilomarStatus', 
                       'ReproductiveStatusAtIntake',
                       'AgeInMonths',
                        'DurationInShelter',
                        'Binary_outcome'])
lky_df
# Out:
#          PrimaryColor            PrimaryBreed OutcomeType BreedCategory  \
# 0               WHITE        PIT BULL TERRIER        EUTH          Pure
# 1               BLACK           BORDER COLLIE    ADOPTION           Mix
# 2                 TAN        GOLDEN RETRIEVER    ADOPTION           Mix
# 3               WHITE      LABRADOR RETRIEVER    ADOPTION          Pure
# 4               BLACK        PIT BULL TERRIER        EUTH          Pure
# ...               ...                     ...         ...           ...
# 42817         APRICOT  DANDIE DINMONT TERRIER    ADOPTION           Mix
# 42818           BLACK  DACHSHUND - WIREHAIRED    ADOPTION          Pure
# 42819  YELLOW BRINDLE               GREYHOUND    ADOPTION           Mix
# 42820           CREAM           CAIRN TERRIER    ADOPTION          Pure
# 42821           BLACK      MINIATURE PINSCHER    TRANSFER          Pure
#
#       Pet_age_category     Sex
# 0                Young    Male
# 1                Young  Female
# ...

# %%
#drop null rows
lky_df = lky_df.dropna(axis=0, subset=["Pet_age_category"])
atx_df = atx_df.dropna(axis=0, subset=["Pet_age_category"])

# %%
##combine the data
df = pd.concat([lky_df, atx_df], axis=0)
df
# Out:
# c:\users\terri\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#       BreedCategory OutcomeType Pet_age_category             PrimaryBreed  \
# 0              Pure        EUTH            Young         PIT BULL TERRIER
# 1               Mix    ADOPTION            Young            BORDER COLLIE
# 2               Mix    ADOPTION            Young         GOLDEN RETRIEVER
# 3              Pure    ADOPTION             Baby       LABRADOR RETRIEVER
# 4              Pure        EUTH            Young         PIT BULL TERRIER
# ...             ...         ...              ...                      ...
# 48020           Mix  Euthanasia           Senior  Miniature Schnauzer Mix
# ...

# %%
##Primary breed column more uniform
df.loc[df['PrimaryBreed'].str.contains('Mix'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('Mix'), 'PrimaryBreed'].str.replace(' Mix', '')
df['PrimaryBreed'] = df["PrimaryBreed"].str.upper()

# %%
##outcome column more uniform and reset index
df['OutcomeType'] = df["OutcomeType"].str.upper()
df = df.reset_index(drop=True)
df
# Out:
#    BreedCategory OutcomeType Pet_age_category                   PrimaryBreed  \
# 0           Pure        EUTH            Young               PIT BULL TERRIER
# 1            Mix    ADOPTION            Young                  BORDER COLLIE
# 2            Mix    ADOPTION            Young               GOLDEN RETRIEVER
# 3           Pure    ADOPTION             Baby             LABRADOR RETRIEVER
# 4           Pure        EUTH            Young               PIT BULL TERRIER
# 5            Mix    TRANSFER             Baby     ST BERNARD - SMOOTH COATED
# 6           Pure        EUTH           Senior               PIT BULL TERRIER
# 7            Mix    TRANSFER            Young   WIRE-HAIRED POINTING GRIFFON
# 8            Mix        EUTH            Young                         BEAGLE
# 9            Mix      FOSTER            Adult                    PLOTT HOUND
# 10           Two    TRANSFER            Young             LABRADOR RETRIEVER
# ...

# %%
#clean up breed column
breed_counts = df.PrimaryBreed.value_counts()
breed_counts.head(30)
# Out:
# PIT BULL                          14720
# LABRADOR RETRIEVER                11915
# CHIHUAHUA                          8595
# GERMAN SHEPHERD                    5915
# BEAGLE                             3558
# BOXER                              2653
# AUSTRALIAN CATTLE DOG              2215
# BORDER COLLIE                      1906
# DACHSHUND                          1875
# SHIH TZU                           1537
# JACK RUSSELL TERRIER               1512
# ROTTWEILER                         1483
# YORKSHIRE TERRIER                  1201
# SIBERIAN HUSKY                     1176
# AUSTRALIAN SHEPHERD                1143
# AMERICAN STAFFORDSHIRE TERRIER     1070
# CHOW CHOW                          1055
# RAT TERRIER                         914
# GREAT PYRENEES                      775
# CAIRN TERRIER                       765
# POINTER                             749
# MINIATURE POODLE                    746
# AMERICAN BULLDOG                    715
# ...

# %%
#STAFFY
df.loc[df['PrimaryBreed'].str.contains('AMERICAN STAFFORDSHIRE TERRIER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('AMERICAN STAFFORDSHIRE TERRIER'), 'PrimaryBreed'].str.replace('AMERICAN STAFFORDSHIRE TERRIER', 'STAFFORDSHIRE')

# %%
#STAFFY
df.loc[df['PrimaryBreed'].str.contains('STAFFORDSHIRE'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('STAFFORDSHIRE'), 'PrimaryBreed'].str.replace('STAFFORDSHIRE', 'AMERICAN STAFFORDSHIRE TERRIER')

# %%
#PITTIE
df.loc[df['PrimaryBreed'].str.contains('PIT BULL TERRIER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('PIT BULL TERRIER'), 'PrimaryBreed'].str.replace('PIT BULL TERRIER', 'PIT BULL')

# %%
#PITTIE
df.loc[df['PrimaryBreed'].str.contains('AMERICAN PIT BULL'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('AMERICAN PIT BULL'), 'PrimaryBreed'].str.replace('AMERICAN PIT BULL', 'PIT BULL')

# %%
#GSD
df.loc[df['PrimaryBreed'].str.contains('GERMAN SHEPHERD DOG'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('GERMAN SHEPHERD DOG'), 'PrimaryBreed'].str.replace('GERMAN SHEPHERD DOG', 'GERMAN SHEPHERD')

# %%
#JRT
df.loc[df['PrimaryBreed'].str.contains('JACK RUSS TER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('JACK RUSS TER'), 'PrimaryBreed'].str.replace('JACK RUSS TER', 'JACK RUSSELL TERRIER')

# %%
#CHI
df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA SHORTHAIR'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA SHORTHAIR'), 'PrimaryBreed'].str.replace('CHIHUAHUA SHORTHAIR', 'CHIHUAHUA')

# %%
#CHI
df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA LONGHAIR'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA LONGHAIR'), 'PrimaryBreed'].str.replace('CHIHUAHUA LONGHAIR', 'CHIHUAHUA')

# %%
#CHI
df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - SMOOTH COATED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - SMOOTH COATED'), 'PrimaryBreed'].str.replace('CHIHUAHUA - SMOOTH COATED', 'CHIHUAHUA')

# %%
#CHI
df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - LONG HAIRED'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('CHIHUAHUA - LONG HAIRED'), 'PrimaryBreed'].str.replace('CHIHUAHUA - LONG HAIRED', 'CHIHUAHUA')

# %%
#ACD 
df.loc[df['PrimaryBreed'].str.contains('QUEENSLAND HEELER'), 'PrimaryBreed'] = df.loc[df['PrimaryBreed'].str.contains('QUEENSLAND HEELER'), 'PrimaryBreed'].str.replace('QUEENSLAND HEELER', 'AUSTRALIAN CATTLE DOG')

# %%
top_20_breed = breed_counts.head(20)
top_10_breed = breed_counts.head(10)
top_20_breed.sum()
# Out:
# 65983

# %%
t20 = round(top_20_breed.sum() / breed_counts.sum(), 4)*100
t10 = round(top_10_breed.sum() / breed_counts.sum(), 4)*100
print(f"{t20}% of data is in top 20 breeds")
print(f"{t10}% of data is in top 10 breeds")
# Out:
# 73.68% of data is in top 20 breeds
# 61.29% of data is in top 10 breeds

# %%
#clean up outcome type column
outcome_counts = df.OutcomeType.value_counts()
outcome_counts
# Out:
# ADOPTION      45027
# TRANSFER      23564
# EUTHANASIA    16124
# RELEASED       2249
# DISPOSAL        979
# FOSTER          859
# DIED            476
# MISSING         243
# NO SHOW          22
# ET PROCESS        8
# RELEASE           5
# MISSING EX        2
# Name: OutcomeType, dtype: int64

# %%
df.loc[df['OutcomeType'].str.contains('RTO-ADOPT'), 'OutcomeType'] = df.loc[df['OutcomeType'].str.contains('RTO-ADOPT'), 'OutcomeType'].str.replace('RTO-ADOPT', 'ADOPTION')

# %%
df.loc[df['OutcomeType'].str.contains('RTF'), 'OutcomeType'] = df.loc[df['OutcomeType'].str.contains('RTF'), 'OutcomeType'].str.replace('RTF', 'FOSTER')

# %%
df.loc[df['OutcomeType'].str.contains('TRANSPORT'), 'OutcomeType'] = df.loc[df['OutcomeType'].str.contains('TRANSPORT'), 'OutcomeType'].str.replace('TRANSPORT', 'TRANSFER')

# %%
df.loc[df['OutcomeType'].str.contains('EUTHANASIA'), 'OutcomeType'] = df.loc[df['OutcomeType'].str.contains('EUTHANASIA'), 'OutcomeType'].str.replace('EUTHANASIA', 'EUTH')

# %%
df.loc[df['OutcomeType'].str.contains('EUTH'), 'OutcomeType'] = df.loc[df['OutcomeType'].str.contains('EUTH'), 'OutcomeType'].str.replace('EUTH', 'EUTHANASIA')

# %%
df.loc[df['OutcomeType'].str.contains('RELOCATE'), 'OutcomeType'] = df.loc[df['OutcomeType'].str.contains('RELOCATE'), 'OutcomeType'].str.replace('RELOCATE', 'TRANSFER')

# %%
remove = ['RELEASED', 'DIED', 'MISSING', 'NO SHOW', 'ET PROCESS', 'RELEASE', 'MISSING EX', 'DISPOSAL']
# 89558 rows before
for index, row in df.iterrows():
    if row[1] in remove:
        df.drop(index, inplace=True)
df
# Out:
#       BreedCategory OutcomeType Pet_age_category         PrimaryBreed  \
# 0              Pure  EUTHANASIA            Young             PIT BULL
# 1               Mix    ADOPTION            Young        BORDER COLLIE
# 2               Mix    ADOPTION            Young     GOLDEN RETRIEVER
# 3              Pure    ADOPTION             Baby   LABRADOR RETRIEVER
# 4              Pure  EUTHANASIA            Young             PIT BULL
# ...             ...         ...              ...                  ...
# 89553           Mix  EUTHANASIA           Senior  MINIATURE SCHNAUZER
# 89554           Mix    ADOPTION           Senior            CHIHUAHUA
# 89555          Pure  EUTHANASIA           Senior     MINIATURE POODLE
# 89556           Mix    TRANSFER           Senior            CHIHUAHUA
# 89557           Two  EUTHANASIA           Senior            CHIHUAHUA
#
#       PrimaryColor     Sex
# 0            WHITE    Male
# 1            BLACK  Female
# 2              TAN    Male
# ...

# %%
outcome_counts2 = df.OutcomeType.value_counts()
outcome_counts2
# Out:
# ADOPTION      45027
# TRANSFER      23564
# EUTHANASIA    16124
# FOSTER          859
# Name: OutcomeType, dtype: int64

# %%
breed_counts2 = df.PrimaryBreed.value_counts()
breed_counts2.head(20)
# Out:
# PIT BULL                          14013
# LABRADOR RETRIEVER                11523
# CHIHUAHUA                          8272
# GERMAN SHEPHERD                    5681
# BEAGLE                             3351
# BOXER                              2475
# AUSTRALIAN CATTLE DOG              2181
# BORDER COLLIE                      1856
# DACHSHUND                          1790
# JACK RUSSELL TERRIER               1430
# SHIH TZU                           1399
# ROTTWEILER                         1370
# SIBERIAN HUSKY                     1107
# YORKSHIRE TERRIER                  1098
# AUSTRALIAN SHEPHERD                1094
# AMERICAN STAFFORDSHIRE TERRIER     1036
# CHOW CHOW                           973
# RAT TERRIER                         882
# GREAT PYRENEES                      760
# CAIRN TERRIER                       748
# Name: PrimaryBreed, dtype: int64

# %%
top_20_breeds = pd.DataFrame(breed_counts2.head(20))
top_breeds = top_20_breeds.reset_index(drop = False)
top_breeds = top_breeds.rename(columns={"index": "PrimaryBreed", "PrimaryBreed": "count"})
top_breeds
# Out:
#                       PrimaryBreed  count
# 0                         PIT BULL  14013
# 1               LABRADOR RETRIEVER  11523
# 2                        CHIHUAHUA   8272
# 3                  GERMAN SHEPHERD   5681
# 4                           BEAGLE   3351
# 5                            BOXER   2475
# 6            AUSTRALIAN CATTLE DOG   2181
# 7                    BORDER COLLIE   1856
# 8                        DACHSHUND   1790
# 9             JACK RUSSELL TERRIER   1430
# 10                        SHIH TZU   1399
# 11                      ROTTWEILER   1370
# 12                  SIBERIAN HUSKY   1107
# 13               YORKSHIRE TERRIER   1098
# 14             AUSTRALIAN SHEPHERD   1094
# 15  AMERICAN STAFFORDSHIRE TERRIER   1036
# 16                       CHOW CHOW    973
# 17                     RAT TERRIER    882
# 18                  GREAT PYRENEES    760
# 19                   CAIRN TERRIER    748

# %%
#make breed outcome counts csv
a_count = []
t_count = []
f_count = []
e_count = []

for index, row in top_breeds.iterrows():
    breed = row[0]  
    a_sum = 0
    t_sum = 0
    f_sum = 0
    e_sum = 0
    
    for index2, row2 in df.iterrows(): 
        
        if row2[3] == breed:
            outcome = row2[1]
          
            if outcome == 'ADOPTION':
                a_sum += 1
            elif outcome == 'EUTHANASIA':
                e_sum +=1
            elif outcome == 'TRANSFER':
                t_sum +=1
            else:
                f_sum +=1
    a_count.append(a_sum)
    e_count.append(e_sum)
    t_count.append(t_sum)
    f_count.append(f_sum)
            
           
a_count
# Out:
# [5533,
#  6388,
#  5102,
#  2965,
#  1609,
#  1269,
#  1500,
#  1048,
#  1115,
#  838,
#  532,
#  534,
#  687,
#  576,
#  637,
#  650,
#  194,
#  554,
#  424,
#  517]

# %%
breeds_df = top_breeds
breeds_df['Adoption'] = a_count
breeds_df['Euthanasia'] = e_count
breeds_df['Transfer'] = t_count
breeds_df['Foster'] = f_count
breeds_df
# Out:
#                       PrimaryBreed  count  Adoption  Euthanasia  Transfer  \
# 0                         PIT BULL  14013      5533        5405      2894
# 1               LABRADOR RETRIEVER  11523      6388        1895      3145
# 2                        CHIHUAHUA   8272      5102         521      2530
# 3                  GERMAN SHEPHERD   5681      2965        1160      1516
# 4                           BEAGLE   3351      1609         709       981
# 5                            BOXER   2475      1269         519       662
# 6            AUSTRALIAN CATTLE DOG   2181      1500         122       547
# 7                    BORDER COLLIE   1856      1048         274       520
# 8                        DACHSHUND   1790      1115         126       542
# 9             JACK RUSSELL TERRIER   1430       838         154       415
# 10                        SHIH TZU   1399       532         187       662
# 11                      ROTTWEILER   1370       534         598       222
# ...

# %%
#make gender outcome types csv
a_count = []
t_count = []
f_count = []
e_count = []
gender = ['Female', 'Male']

for g in gender:
    a_sum = 0
    t_sum = 0
    f_sum = 0
    e_sum = 0
    
    for index, row in df.iterrows(): 
    
        if row[5] == g:
            outcome = row[1]
            if outcome == 'ADOPTION':
                a_sum += 1
            elif outcome == 'EUTHANASIA':
                e_sum +=1
            elif outcome == 'TRANSFER':
                t_sum +=1
            else:
                f_sum +=1

    a_count.append(a_sum)
    e_count.append(e_sum)
    t_count.append(t_sum)
    f_count.append(f_sum)

# %%
gender_df = pd.DataFrame(list(zip(gender, a_count)), 
               columns =['Sex', 'Adoption']) 
gender_df['Euthanasia'] = e_count
gender_df['Transfer'] = t_count
gender_df['Foster'] = f_count
gender_df
# Out:
#       Sex  Adoption  Euthanasia  Transfer  Foster
# 0  Female     21672        7115     11113     456
# 1    Male     23355        9009     12451     403

# %%
#make age outcome count csv
a_count = []
t_count = []
f_count = []
e_count = []
age_cate = ['Baby', 'Young', 'Adult', 'Senior']

for age in age_cate:
    a_sum = 0
    t_sum = 0
    f_sum = 0
    e_sum = 0
    
    for index, row in df.iterrows(): 
    
        if row[2] == age:
            outcome = row[1]
            if outcome == 'ADOPTION':
                a_sum += 1
            elif outcome == 'EUTHANASIA':
                e_sum +=1
            elif outcome == 'TRANSFER':
                t_sum +=1
            else:
                f_sum +=1

    a_count.append(a_sum)
    e_count.append(e_sum)
    t_count.append(t_sum)
    f_count.append(f_sum)

# %%
age_group_df = pd.DataFrame(list(zip(age_cate, a_count)), 
               columns =['Age Group', 'Adoption']) 
age_group_df['Euthanasia'] = e_count
age_group_df['Transfer'] = t_count
age_group_df['Foster'] = f_count
age_group_df
# Out:
#   Age Group  Adoption  Euthanasia  Transfer  Foster
# 0      Baby     11880        1709      5439     280
# 1     Young     20871        4504      9143     214
# 2     Adult     10080        5328      6716     262
# 3    Senior      2196        4583      2266     103

# %%
# df['PrimaryColor'] = df["PrimaryColor"].str.upper()
color_counts = df.PrimaryColor.value_counts()
color_counts
# Out:
# BLACK       24278
# WHITE       14943
# BROWN       14647
# TAN         11503
# BRINDLE      4967
# TRICOLOR     4086
# BLUE         4084
# RED          3561
# YELLOW       1504
# MERLE         841
# SABLE         824
# TICK          336
# Name: PrimaryColor, dtype: int64

# %%
#Yellows
df.loc[df['PrimaryColor'].str.contains('GOLD'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('GOLD'), 'PrimaryColor'].str.replace('GOLD', 'YELLOW')

# %%
#tans
df.loc[df['PrimaryColor'].str.contains('CHAMPAIGN'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('CHAMPAIGN'), 'PrimaryColor'].str.replace('CHAMPAIGN', 'TAN')
df.loc[df['PrimaryColor'].str.contains('BEIGE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BEIGE'), 'PrimaryColor'].str.replace('BEIGE', 'TAN')
df.loc[df['PrimaryColor'].str.contains('BLONDE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLONDE'), 'PrimaryColor'].str.replace('BLONDE', 'TAN')
df.loc[df['PrimaryColor'].str.contains('APRICOT'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('APRICOT'), 'PrimaryColor'].str.replace('APRICOT', 'TAN')
df.loc[df['PrimaryColor'].str.contains('BUFF'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BUFF'), 'PrimaryColor'].str.replace('BUFF', 'TAN')
df.loc[df['PrimaryColor'].str.contains('FAWN'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('FAWN'), 'PrimaryColor'].str.replace('FAWN', 'TAN')

# %%
#blue
df.loc[df['PrimaryColor'].str.contains('BLUE SMOKE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLUE SMOKE'), 'PrimaryColor'].str.replace('BLUE SMOKE', 'BLUE')
df.loc[df['PrimaryColor'].str.contains('BLUE CREAM'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLUE CREAM'), 'PrimaryColor'].str.replace('BLUE CREAM', 'BLUE')
df.loc[df['PrimaryColor'].str.contains('SILVER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('SILVER'), 'PrimaryColor'].str.replace('SILVER', 'BLUE')
df.loc[df['PrimaryColor'].str.contains('GRAY'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('GRAY'), 'PrimaryColor'].str.replace('GRAY', 'BLUE')

# %%
#brindle
df.loc[df['PrimaryColor'].str.contains('CREAM TIGER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('CREAM TIGER'), 'PrimaryColor'].str.replace('CREAM TIGER', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('YELLOW BRINDLE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('YELLOW BRINDLE'), 'PrimaryColor'].str.replace('YELLOW BRINDLE', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('BROWN TABBY'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BROWN TABBY'), 'PrimaryColor'].str.replace('BROWN TABBY', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('GRAY TIGER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('GRAY TIGER'), 'PrimaryColor'].str.replace('GRAY TIGER', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('BLACK TIGER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLACK TIGER'), 'PrimaryColor'].str.replace('BLACK TIGER', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('BROWN TIGER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BROWN TIGER'), 'PrimaryColor'].str.replace('BROWN TIGER', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('BLUE TIGER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLUE TIGER'), 'PrimaryColor'].str.replace('BLUE TIGER', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('BLACK BRINDLE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLACK BRINDLE'), 'PrimaryColor'].str.replace('BLACK BRINDLE', 'BRINDLE')
df.loc[df['PrimaryColor'].str.contains('BROWN BRINDLE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BROWN BRINDLE'), 'PrimaryColor'].str.replace('BROWN BRINDLE', 'BRINDLE')

# %%
#MERLE
df.loc[df['PrimaryColor'].str.contains('BLUE MERLE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLUE MERLE'), 'PrimaryColor'].str.replace('BLUE MERLE', 'MERLE')
df.loc[df['PrimaryColor'].str.contains('RED MERLE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('RED MERLE'), 'PrimaryColor'].str.replace('RED MERLE', 'MERLRE')
df.loc[df['PrimaryColor'].str.contains('BROWN MERLE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BROWN MERLE'), 'PrimaryColor'].str.replace('BROWN MERLE', 'MERLE')
df.loc[df['PrimaryColor'].str.contains('MERLRE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('MERLRE'), 'PrimaryColor'].str.replace('MERLRE', 'MERLE')

# %%
#red
df.loc[df['PrimaryColor'].str.contains('ORANGE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('ORANGE'), 'PrimaryColor'].str.replace('ORANGE', 'RED')
df.loc[df['PrimaryColor'].str.contains('RUDDY'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('RUDDY'), 'PrimaryColor'].str.replace('RUDDY', 'RED')

# %%
#CHOCOLATE
df.loc[df['PrimaryColor'].str.contains('CHOCOLATE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('CHOCOLATE'), 'PrimaryColor'].str.replace('CHOCOLATE', 'BROWN')
df.loc[df['PrimaryColor'].str.contains('LIVER'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('LIVER'), 'PrimaryColor'].str.replace('LIVER', 'BROWN')

# %%
#WHITE
df.loc[df['PrimaryColor'].str.contains('CREAM'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('CREAM'), 'PrimaryColor'].str.replace('CREAM', 'WHITE')

# %%
#TICK
df.loc[df['PrimaryColor'].str.contains('RED TICKED'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('RED TICKED'), 'PrimaryColor'].str.replace('RED TICKED', 'TICK')
df.loc[df['PrimaryColor'].str.contains('BLUE TICKED'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLUE TICKED'), 'PrimaryColor'].str.replace('BLUE TICKED', 'TICK')
df.loc[df['PrimaryColor'].str.contains('RED TICK'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('RED TICK'), 'PrimaryColor'].str.replace('RED TICK', 'TICK')
df.loc[df['PrimaryColor'].str.contains('BLUE TICK'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLUE TICK'), 'PrimaryColor'].str.replace('BLUE TICK', 'TICK')
df.loc[df['PrimaryColor'].str.contains('LIVER TICK'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('LIVER TICK'), 'PrimaryColor'].str.replace('LIVER TICK', 'TICK')
df.loc[df['PrimaryColor'].str.contains('BROWN TICK'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BROWN TICK'), 'PrimaryColor'].str.replace('BROWN TICK', 'TICK')

# %%
#BLACK
df.loc[df['PrimaryColor'].str.contains('BLACK SMOKE'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('BLACK SMOKE'), 'PrimaryColor'].str.replace('BLACK SMOKE', 'BLACK')

# %%
#SABLE
df.loc[df['PrimaryColor'].str.contains('AGOUTI'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('AGOUTI'), 'PrimaryColor'].str.replace('AGOUTI', 'SABLE')

# %%
#TRICOLOR
df.loc[df['PrimaryColor'].str.contains('CALICO'), 'PrimaryColor'] = df.loc[df['PrimaryColor'].str.contains('CALICO'), 'PrimaryColor'].str.replace('CALICO', 'TRICOLOR')

# %%
colors_df = pd.DataFrame(color_counts)
colors_df = colors_df.reset_index(drop = False)
colors_df = colors_df.rename(columns={"index": "PrimaryColor", "PrimaryColor": "count"})
colors_df
# Out:
#    PrimaryColor  count
# 0         BLACK  24278
# 1         WHITE  14943
# 2         BROWN  14647
# 3           TAN  11503
# 4       BRINDLE   4967
# 5      TRICOLOR   4086
# 6          BLUE   4084
# 7           RED   3561
# 8        YELLOW   1504
# 9         MERLE    841
# 10        SABLE    824
# 11         TICK    336

# %%
#make color outcome counts csv
a_count = []
t_count = []
f_count = []
e_count = []

for index, row in colors_df.iterrows():
    color = row[0]  
    a_sum = 0
    t_sum = 0
    f_sum = 0
    e_sum = 0
    
    for index2, row2 in df.iterrows(): 
        
        if row2[4] == color:
            outcome = row2[1]
          
            if outcome == 'ADOPTION':
                a_sum += 1
            elif outcome == 'EUTHANASIA':
                e_sum +=1
            elif outcome == 'TRANSFER':
                t_sum +=1
            else:
                f_sum +=1
    a_count.append(a_sum)
    e_count.append(e_sum)
    t_count.append(t_sum)
    f_count.append(f_sum)

# %%
colors_df['Adoption'] = a_count
colors_df['Euthanasia'] = e_count
colors_df['Transfer'] = t_count
colors_df['Foster'] = f_count
colors_df
# Out:
#    PrimaryColor  count  Adoption  Euthanasia  Transfer  Foster
# 0         BLACK  24278     12501        5062      6475     240
# 1         WHITE  14943      7936        2260      4590     157
# 2         BROWN  14647      7501        3169      3834     143
# 3           TAN  11503      6333        1839      3213     118
# 4       BRINDLE   4967      2504        1200      1203      60
# 5      TRICOLOR   4086      2323         583      1145      35
# 6          BLUE   4084      2096         863      1067      58
# 7           RED   3561      1851         720       965      25
# 8        YELLOW   1504       685         309       494      16
# 9         MERLE    841       517          76       242       6
# 10        SABLE    824       539          34       251       0
# 11         TICK    336       241           9        85       1

# %%
breeds_df.to_csv('breeds.csv', index=False)
age_group_df.to_csv('age_group.csv', index=False)
gender_df.to_csv('gender.csv', index=False)
colors_df.to_csv('colors.csv', index=False)
