# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/test.csv")
df
# Out:
#           ID      Name             DateTime AnimalType SexuponOutcome  \
# 0          1    Summer  2015-10-12 12:15:00        Dog  Intact Female
# 1          2  Cheyenne  2014-07-26 17:59:00        Dog  Spayed Female
# 2          3       Gus  2016-01-13 12:20:00        Cat  Neutered Male
# 3          4     Pongo  2013-12-28 18:12:00        Dog    Intact Male
# 4          5   Skooter  2015-09-24 17:59:00        Dog  Neutered Male
# ...      ...       ...                  ...        ...            ...
# 11451  11452       NaN  2014-07-08 14:50:00        Cat  Neutered Male
# 11452  11453       NaN  2014-10-21 12:57:00        Cat  Intact Female
# 11453  11454       NaN  2014-09-29 09:00:00        Cat  Intact Female
# 11454  11455     Rambo  2015-09-05 17:16:00        Dog  Neutered Male
# 11455  11456     Gusto  2014-07-12 18:40:00        Dog    Intact Male
#
#       AgeuponOutcome                           Breed        Color
# ...

# %%
df = df.query("AnimalType == 'Dog'")
df
# Out:
#           ID      Name             DateTime AnimalType SexuponOutcome  \
# 0          1    Summer  2015-10-12 12:15:00        Dog  Intact Female
# 1          2  Cheyenne  2014-07-26 17:59:00        Dog  Spayed Female
# 3          4     Pongo  2013-12-28 18:12:00        Dog    Intact Male
# 4          5   Skooter  2015-09-24 17:59:00        Dog  Neutered Male
# 5          6      Beau  2015-06-23 11:17:00        Dog  Neutered Male
# ...      ...       ...                  ...        ...            ...
# 11448  11449       NaN  2014-08-17 17:48:00        Dog  Spayed Female
# 11449  11450    Caicos  2015-07-20 14:55:00        Dog  Spayed Female
# 11450  11451     Cosmo  2015-11-05 17:19:00        Dog  Neutered Male
# 11454  11455     Rambo  2015-09-05 17:16:00        Dog  Neutered Male
# 11455  11456     Gusto  2014-07-12 18:40:00        Dog    Intact Male
#
#       AgeuponOutcome                           Breed             Color
# ...

# %%
df2 = pd.read_csv("data/train.csv")
df2
# Out:
#       AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0      A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 1      A656520    Emily  2013-10-13 12:44:00       Euthanasia      Suffering
# 2      A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
# 3      A683430      NaN  2014-07-11 19:09:00         Transfer        Partner
# 4      A667013      NaN  2013-11-15 12:52:00         Transfer        Partner
# ...        ...      ...                  ...              ...            ...
# 26724  A702446      NaN  2015-05-14 11:56:00         Transfer        Partner
# 26725  A718934      NaN  2016-01-20 18:59:00         Transfer           SCRP
# 26726  A698128     Zeus  2015-03-09 13:33:00         Adoption            NaN
# 26727  A677478      NaN  2014-04-27 12:22:00         Transfer        Partner
# 26728  A706629      NaN  2015-07-02 09:00:00         Transfer           SCRP
#
# ...

# %%
df2 = df2.query("AnimalType == 'Dog'")
df2
# Out:
#       AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0      A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 2      A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
# 4      A667013      NaN  2013-11-15 12:52:00         Transfer        Partner
# 5      A677334     Elsa  2014-04-25 13:04:00         Transfer        Partner
# 8      A671784     Lucy  2014-02-04 17:17:00         Adoption            NaN
# ...        ...      ...                  ...              ...            ...
# 26716  A697158      Max  2015-05-02 21:04:00         Adoption        Offsite
# 26717  A519949    Bella  2014-06-30 17:34:00  Return_to_owner            NaN
# 26718  A701044      NaN  2015-04-28 14:26:00         Adoption            NaN
# 26723  A716997     Zeus  2016-01-29 18:52:00         Adoption            NaN
# 26726  A698128     Zeus  2015-03-09 13:33:00         Adoption            NaN
#
# ...

# %%
merged = pd.concat([df,df2])
merged
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       AgeuponOutcome AnimalID AnimalType                           Breed  \
# 0          10 months      NaN        Dog          Labrador Retriever Mix
# 1            2 years      NaN        Dog  German Shepherd/Siberian Husky
# 3           4 months      NaN        Dog               Collie Smooth Mix
# 4            2 years      NaN        Dog            Miniature Poodle Mix
# 5            3 years      NaN        Dog                      Beagle Mix
# ...              ...      ...        ...                             ...
# 26716       2 months  A697158        Dog                Newfoundland Mix
# ...

# %%
merged.to_csv("merged_clean.csv")

# %%
merged.query("Breed == 'Beagle Mix' & OutcomeType == 'Adoption'")
# Out:
#       AgeuponOutcome AnimalID AnimalType       Breed                Color  \
# 735           1 year  A677236        Dog  Beagle Mix            Red/White
# 1027        2 months  A689773        Dog  Beagle Mix         White/Orange
# 2052        2 months  A675885        Dog  Beagle Mix          Brown/White
# 3254          1 year  A715163        Dog  Beagle Mix  White/Brown Brindle
# 3682         2 years  A666660        Dog  Beagle Mix            Tan/White
# 4446         8 years  A683033        Dog  Beagle Mix          Brown/White
# 4956         8 years  A692390        Dog  Beagle Mix            Black/Tan
# 5104        2 months  A714383        Dog  Beagle Mix            Brown/Tan
# 5640         1 month  A685397        Dog  Beagle Mix             Tricolor
# 5693         3 years  A666325        Dog  Beagle Mix          Black/White
# 7456         7 years  A691849        Dog  Beagle Mix             Tricolor
# 8228        2 months  A689774        Dog  Beagle Mix            Tan/White
# ...
